# %% [markdown]
# # Use Long Short Term Memory (LSTM) to Predict Revenue
#
# In this project, I created a Python notebook for predicting revenue of Bank using Long short Term Memeory which are widely used for sequence prediction problems and have proven to be extremely effective.
#
# LTSM has three gates:
#
# - **The input gate**: The input gate adds information to the cell state
#
# - **The forget gate**: This removes information that are not required by the model
#
# - **The output gate**: Select the information to be shown as output
#
#
#
# ## Understanding the Problem Statement
#
# Our focus is to do the technical analysis by analyzing the company’s future profitability on the basis of its current business financial performance by reading the charts and using statistical figures to identify the trends.
#
#
#
# ## Data Sources:
# * revenue_2009_2016.csv :  Processed data as an output from the data-preparation. Notebook available [here.](https://github.com/CFerraren/PyBank/blob/master/1-Data_Prep.ipynb)
#
#
#
#
# ### Task is to create a Python script that analyzes the records to calculate each of the following:
#
# - Use LTSM as a black box and check it's performance on our financial bank data.
#
# - Split our data into train and validation sets to verify our predictions.
#
# - Plot results.
#
#
# ### Changes:
#
# - 02-12-2018: Started the project
#
# - 12-11-2018: Updated the project using Python Pandas and added visualization using matplotlib, Tableau, and Univariate Linear Regression Machine learning to predict future bank revenue.
#
#
# ---

# %% [markdown]
# #### Import Libraries

# %%
#import packages
import numpy as np
import pandas as pd
import os
import sklearn.preprocessing as preproc

#to plot within the notebook
import matplotlib.pyplot as plt
# %matplotlib inline

#use seaborn to prettify the plots
import seaborn as sns
sns.set_style('whitegrid')

import warnings
warnings.filterwarnings('ignore')

#display pd typeformat
pd.set_option('display.float_format', '{:,.0f}'.format)

# %%
#setting figure size
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12,5

# %% [markdown]
# #### Load Data

# %%
#directory and filename
dir = 'data/processed/'
file = 'revenue_2009_2016.csv'

# %%
#load csv into dataframe and print the head
data = pd.read_csv(os.path.join(dir, file), parse_dates=['Date'], index_col='Date')

# %%
#make a copy
df = data.copy()

# %%
df.describe().T
# Out:
#          count    mean     std        min     25%     50%       75%       max
# Revenue     86 650,527 680,460 -1,063,151 279,551 686,900 1,118,162 2,211,086

# %%
#transform to make it more gaussian-like
yeo_johnson = preproc.PowerTransformer(method='yeo-johnson')
df['yeo_johnson'] = yeo_johnson.fit_transform(df[['Revenue']])

# %%
df[:5]
# Out:
#              Revenue  yeo_johnson
# Date
# 2009-01-01   943,690            0
# 2009-02-01 1,062,565            1
# 2009-03-01   210,079           -1
# 2009-04-01  -735,286           -2
# 2009-05-01   842,933            0

# %%
train = df[:72]
valid = df[72:]

# %%
#importing required libraries
from keras.models import Sequential
from keras.layers import LSTM

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(units=1000, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(units=1000))
model.add(Dense(1))

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs=1, batch_size=1, verbose=2)
# Out:
# Epoch 1/1
#  - 18s - loss: 0.0764

# %%
#predicting values, using past data from the train data
inputs = new_data[len(new_data) - len(valid) - 1:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

# %%
X_test = []
for i in range(1,inputs.shape[0]):
    X_test.append(inputs[i-1:i,0])
    
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))

pred_rvn = model.predict(X_test)
pred_rvn = scaler.inverse_transform(pred_rvn)

# %%
rms=np.sqrt(np.mean(np.power((valid-pred_rvn),2)))
rms
# Out:
# 982067.6911654668

# %%
#for plotting
train = new_data[:78]
valid = new_data[78:]
valid['Predictions'] = pred_rvn
plt.plot(train['Revenue'])
plt.plot(valid[['Revenue','Predictions']])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# ...
