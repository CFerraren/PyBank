# %% [markdown]
# # Data Preparation to Analyze 2012-2016 Revenue Performance
#
# In this challenge, I created a Python script for analyzing the financial records of PyBank.
#
# This notebook will bring all the data sources together and format them for further analysis.
#
#
# ## Data Sources:
# * budget_data_1.csv : John in Finance generated file from SAP
# * budget_data_2.csv : Michael in Finance generated file from SAP
#
# Each dataset is composed of two columns: Date and Revenue.
#
#
#
# ### Task on this notebbook is to prepare data from various sources for further analysis.
#
# - Read data from various sources.
#
# - Format data to correct data types.
#
# - Merge Data
#
# - Check for missing/NaN values.
#
# - Check for duplicate values
#
#
# ### Changes:
#
# - 02-12-2018: Started the project
#
# - 12-11-2018: Updated the project using Python Pandas and added visualization using matplotlib, Tableau, and Univariate Linear Regression Machine learning to predict future bank revenue.
#
#
# ---

# %%
# Import Libraries

import pandas as pd
import os

# %%
# Directory Location and Filenames

dir = 'data/raw'
file1 = 'budget_data_1.csv'
file2 = 'budget_data_2.csv'

# %%
# Load Data into csv

df1 = pd.read_csv(os.path.join(dir,file1))
df2 = pd.read_csv(os.path.join(dir,file2))

# %%
# Take a peek

df1[:5]
# Out:
#      Date  Revenue
# 0  Oct-12  1154293
# 1  Nov-12   885773
# 2  Dec-12  -448704
# 3  Jan-13   563679
# 4  Feb-13   555394

# %% [markdown]
# ###  Date Column
#
# ````- Since we have a date column on our dataframe, we made sure that we need to store it as date format.````
#
# ---

# %%
df1.dtypes
# Out:
# Date       object
# Revenue     int64
# dtype: object

# %% [markdown]
# ***Date*** - ```We need to format it as a date format.```
#
# ---

# %%
# Define dates as datetime objects

df1['Date'] = pd.to_datetime(df1['Date'], format='%b-%y')

# %% [markdown]
# Use python strftime reference: http://strftime.org/ to format the datetime
#
# ```%b	Month as locale’s abbreviated name.```
#
# ```%y	Year without century as a zero-padded decimal number.```
#
# ---

# %%
# Verify the data type of the date column

df1.dtypes
# Out:
# Date       datetime64[ns]
# Revenue             int64
# dtype: object

# %%
# Take a peak

df1[:5]
# Out:
#         Date  Revenue
# 0 2012-10-01  1154293
# 1 2012-11-01   885773
# 2 2012-12-01  -448704
# 3 2013-01-01   563679
# 4 2013-02-01   555394

# %%
df2[:5]
# Out:
#        Date  Revenue
# 0  Jan-2009   943690
# 1  Feb-2009  1062565
# 2  Mar-2009   210079
# 3  Apr-2009  -735286
# 4  May-2009   842933

# %%
# Change the Datatype of date

df2['Date'] = pd.to_datetime(df2['Date'], format='%b-%Y')

# %% [markdown]
# Use python strftime reference: http://strftime.org/ to format the datetime
#
# ```%b	Month as locale’s abbreviated name.```
#
# ```%Y	Year with century as a decimal number.```
#
# ---

# %%
df2.dtypes
# Out:
# Date       datetime64[ns]
# Revenue             int64
# dtype: object

# %%
df2[:5]
# Out:
#         Date  Revenue
# 0 2009-01-01   943690
# 1 2009-02-01  1062565
# 2 2009-03-01   210079
# 3 2009-04-01  -735286
# 4 2009-05-01   842933

# %% [markdown]
# ## Merge Dataframes

# %%
# Merge the two Dataframe

df = pd.merge(df1, df2, how='outer', on='Date')

# Highlight the NaN values

df.tail().style.highlight_null(null_color='red')
# Out:
# <style  type="text/css" >
#     #T_ba7f7b50_fda8_11e8_bb52_0242ac110002row0_col1 {
#             background-color:  red;
#         }    #T_ba7f7b50_fda8_11e8_bb52_0242ac110002row1_col1 {
#             background-color:  red;
#         }    #T_ba7f7b50_fda8_11e8_bb52_0242ac110002row2_col1 {
#             background-color:  red;
#         }    #T_ba7f7b50_fda8_11e8_bb52_0242ac110002row3_col1 {
#             background-color:  red;
#         }    #T_ba7f7b50_fda8_11e8_bb52_0242ac110002row4_col1 {
#             background-color:  red;
#         }</style>
# <table id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Date</th>
#         <th class="col_heading level0 col1" >Revenue_x</th>
#         <th class="col_heading level0 col2" >Revenue_y</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002level0_row0" class="row_heading level0 row0" >81</th>
#         <td id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002row0_col0" class="data row0 col0" >2012-05-01 00:00:00</td>
#         <td id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002row0_col1" class="data row0 col1" >nan</td>
#         <td id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002row0_col2" class="data row0 col2" >51905</td>
#     </tr>    <tr>
#         <th id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002level0_row1" class="row_heading level0 row1" >82</th>
#         <td id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002row1_col0" class="data row1 col0" >2012-06-01 00:00:00</td>
#         <td id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002row1_col1" class="data row1 col1" >nan</td>
#         <td id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002row1_col2" class="data row1 col2" >415204</td>
#     </tr>    <tr>
#         <th id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002level0_row2" class="row_heading level0 row2" >83</th>
#         <td id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002row2_col0" class="data row2 col0" >2012-07-01 00:00:00</td>
#         <td id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002row2_col1" class="data row2 col1" >nan</td>
#         <td id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002row2_col2" class="data row2 col2" >467130</td>
#     </tr>    <tr>
#         <th id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002level0_row3" class="row_heading level0 row3" >84</th>
#         <td id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002row3_col0" class="data row3 col0" >2012-08-01 00:00:00</td>
#         <td id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002row3_col1" class="data row3 col1" >nan</td>
#         <td id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002row3_col2" class="data row3 col2" >270918</td>
#     </tr>    <tr>
#         <th id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002level0_row4" class="row_heading level0 row4" >85</th>
#         <td id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002row4_col0" class="data row4 col0" >2012-09-01 00:00:00</td>
#         <td id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002row4_col1" class="data row4 col1" >nan</td>
#         <td id="T_ba7f7b50_fda8_11e8_bb52_0242ac110002row4_col2" class="data row4 col2" >589902</td>
#     </tr></tbody>
# </table>

# %%
# Check for Null values

df.isnull().sum()
# Out:
# Date          0
# Revenue_x    45
# Revenue_y     0
# dtype: int64

# %%
# Fill the NaN values with 0 to aggregate the Revenue

df = df.fillna(0)
df.tail()
# Out:
#          Date  Revenue_x  Revenue_y
# 81 2012-05-01        0.0      51905
# 82 2012-06-01        0.0     415204
# 83 2012-07-01        0.0     467130
# 84 2012-08-01        0.0     270918
# 85 2012-09-01        0.0     589902

# %%
# Aggregate the Revenue data by adding the Revenue columns from both dataframes

df["Revenue"] = df['Revenue_x'] + df['Revenue_y']
df.tail()
# Out:
#          Date  Revenue_x  Revenue_y   Revenue
# 81 2012-05-01        0.0      51905   51905.0
# 82 2012-06-01        0.0     415204  415204.0
# 83 2012-07-01        0.0     467130  467130.0
# 84 2012-08-01        0.0     270918  270918.0
# 85 2012-09-01        0.0     589902  589902.0

# %%
# Drop the unwanted columns

df = df.drop(['Revenue_x', 'Revenue_y'], axis=1)
df[:5]
# Out:
#         Date    Revenue
# 0 2012-10-01  2211086.0
# 1 2012-11-01  1135852.0
# 2 2012-12-01  -357360.0
# 3 2013-01-01   994779.0
# 4 2013-02-01  1357358.0

# %%
# Sort the dataframe by date

df = df.sort_values(by='Date')
df.style.bar(subset='Revenue', align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 61.3%, transparent 61.3%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 64.9%, transparent 64.9%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 38.9%, transparent 38.9%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 10.0%, #d65f5f 10.0%, #d65f5f 32.5%, transparent 32.5%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 58.2%, transparent 58.2%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 43.4%, transparent 43.4%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 60.4%, transparent 60.4%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 54.6%, transparent 54.6%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 6.9%, #d65f5f 6.9%, #d65f5f 32.5%, transparent 32.5%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 28.0%, #d65f5f 28.0%, #d65f5f 32.5%, transparent 32.5%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 57.9%, transparent 57.9%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 60.5%, transparent 60.5%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 56.9%, transparent 56.9%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 66.6%, transparent 66.6%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 38.0%, transparent 38.0%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 36.2%, transparent 36.2%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 58.2%, transparent 58.2%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 41.9%, transparent 41.9%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 47.8%, transparent 47.8%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 9.6%, #d65f5f 9.6%, #d65f5f 32.5%, transparent 32.5%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent -0.0%, #d65f5f -0.0%, #d65f5f 32.5%, transparent 32.5%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 35.9%, transparent 35.9%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 59.6%, transparent 59.6%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 63.9%, transparent 63.9%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row24_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 10.9%, #d65f5f 10.9%, #d65f5f 32.5%, transparent 32.5%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row25_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 46.4%, transparent 46.4%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row26_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 43.4%, transparent 43.4%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row27_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 35.8%, transparent 35.8%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row28_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 66.4%, transparent 66.4%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row29_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 53.6%, transparent 53.6%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row30_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 52.9%, transparent 52.9%);
#         }    #T_ba9a1abe_fda8_11e8_bb52_0242ac110002row31_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%,

# %%
# Check for Duplicates

df.duplicated(keep='first').sum()
# Out:
# 0

# %%
# Number of items/records in the dataframe

len(df)
# Out:
# 86

# %%
# Save the cleaned file for further analysis

df.to_csv('data/processed/revenue_2009_2016.csv', index=False)
